# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(columns= ["Tipo de Permutación", "Alpha", "Tipo de árbol", "Número de Nodos","Tiempo de Búsqueda (us)", "Memoria Usada (bytes)"])

# %%
df = pd.read_csv("experimento.txt")

# %%
df
# Out:
#   Tipo de Permutación  Alpha Tipo de árbol  Max Número en Array  \
# 0                   S      1             X                   10
# 1                   S      2             X                   10
# 2                   Z      2             Y                   10
# 3                   Z      2             Y                   10
#
#    Número de Nodos  Tiempo de Búsqueda (us)  Memoria Usada (bytes)
# 0                2                      3.0                      2
# 1                4                      2.5                      2
# 2                4                      4.0                      2
# 3                4                      7.0                      2

# %% [markdown]
# ## **Modelamiento del uso de tiempo**

# %% [markdown]
# ### **Comparación**

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.histplot(df,
             x="Tiempo de Búsqueda (us)",
             hue="Tipo de Permutación",
             ax=ax,
             )
ax.set_title("Histograma del Tiempo de Búsqueda")
# Out:
# Text(0.5, 1.0, 'Histograma del Tiempo de Búsqueda')

# %% [markdown]
# ### **Árbol Splay**

# %% [markdown]
# #### Gráfico de tiempos promedio con errorbar

# %%
sns.barplot(df.groupby(by="Tipo de Permutación").get_group("S"),
            x="Tiempo de Búsqueda (us)",
            y="Número de Nodos",
            
            )
# Out:
# <Axes: xlabel='Tiempo de Búsqueda (us)', ylabel='Número de Nodos'>

# %% [markdown]
# #### Regresión no lineal

# %%
def modelo_splay_tree(x):
    return x

# %% [markdown]
# ### **Árbol Rojo-Negro**

# %% [markdown]
# #### Gráfico de tiempos promedio con errorbar

# %% [markdown]
# #### Regresión no lineal

# %%
def modelo_red_black_tree(x):
    return x
